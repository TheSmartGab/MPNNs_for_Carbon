# %%
from ase.visualize import view
from ase.io import read

# %%
data = read("v1/relaxed_configs.extxyz", index = ":")

# %%
view([a.repeat((3,3,1)) for a in data], viewer="ngl")

# %%
data[0].positions
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  1.41994983e+00,  4.70000000e-07],
#        [ 0.00000000e+00,  0.00000000e+00,  3.56967237e+00],
#        [ 1.22971257e+00, -7.09974770e-01,  3.56966731e+00]])
