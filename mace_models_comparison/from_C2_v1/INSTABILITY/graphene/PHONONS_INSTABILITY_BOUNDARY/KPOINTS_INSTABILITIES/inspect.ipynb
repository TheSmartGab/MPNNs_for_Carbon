# %%
from ase.io import Trajectory
from ase.visualize import view

# %%
import os
files = os.listdir("RELAXATIONS")

# %%
from pprint import pprint
pprint(files)
# Out:
# ['nx20_ny15_angle0_rot0.00_amp0.26.traj',
#  'nx20_ny15_angle45_rot0.00_amp0.23.traj',
#  'nx20_ny15_angle90_rot0.00_amp0.18.traj',
#  'nx20_ny15_angle23_rot0.00_amp0.24.traj']

# %%
traj = Trajectory("RELAXATIONS/" + files[2])

# %%
view(traj, viewer = "ngl")

# %%
traj[0].cell
# Out:
# Cell([49.19657879966904, 75.41171311691377, 100.0])

# %%
traj[-1].get_stress()
# Out:
# array([ 9.24848602e-04,  7.53415190e-03,  4.49647777e-32, -1.72217388e-20,
#        -4.27609105e-19, -1.63347984e-04])
