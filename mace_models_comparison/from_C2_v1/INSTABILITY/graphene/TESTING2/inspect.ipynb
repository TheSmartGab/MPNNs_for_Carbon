# %%
import pandas as pd
import numpy as np

# %%
FILE = "kcell_lateral/results.csv"
df = pd.read_csv(FILE)

# %%
df.plot("angle", "cell_a3z")
# Out:
# <Axes: xlabel='angle'>

# %%
import matplotlib.pyplot as plt

# %%
df['metric'] = (df['sxx'] + df['syy']) * df['cell_a3z'] / np.sqrt(2)

# %%
df.plot("angle", "metric")
# Out:
# <Axes: xlabel='angle'>

# %%
df['metric2'] = (df['sxx'] + df['syy']) / np.sqrt(2)

# %%
df.plot("angle", "metric2")
# Out:
# <Axes: xlabel='angle'>
