# %%
import pandas as pd

# %%
FILE = "10_10_1_opt/stress_strain_angle0.00deg.csv"
df = pd.read_csv(FILE)
df.head()
# Out:
#    strain_magnitude  stress_norm       sxx           sxy           sxz  \
# 0          0.150000     0.002649  0.002610  5.243709e-10 -5.156067e-30
# 1          0.155172     0.002681  0.002641 -1.230624e-10 -4.968568e-30
# 2          0.160345     0.002709  0.002668 -1.977866e-10 -7.092953e-30
# 3          0.165517     0.002735  0.002693 -1.209369e-11 -5.314793e-30
# 4          0.170690     0.002758  0.002715  3.291306e-10  4.297554e-30
#
#             syx       syy           syz           szx           szy  \
# 0  5.243709e-10  0.000454  3.112871e-31 -5.156067e-30  3.112871e-31
# 1 -1.230624e-10  0.000463  3.619668e-30 -4.968568e-30  3.619668e-30
# 2 -1.977866e-10  0.000471 -2.562628e-30 -7.092953e-30 -2.562628e-30
# 3 -1.209369e-11  0.000479  6.319326e-30 -5.314793e-30  6.319326e-30
# 4  3.291306e-10  0.000486  2.325421e-30  4.297554e-30  2.325421e-30
#
#             szz
# 0  5.450000e-43
# 1  2.720000e-43
# 2  5.620000e-43
# 3  1.237000e-42
# 4  4.760000e-43

# %%
df.plot("strain_magnitude", "stress_norm")
# Out:
# <Axes: xlabel='strain_magnitude'>
